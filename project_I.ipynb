# %% [markdown]
# # Project I
# ### Wrangling the API data
#
# The point of this exercise is to try data enrichment with data from external APIs. We are going to take data about car crashes in Monroe County, Indiana from 2003 to 2015 and try to figure out the weather during the accident and how many bars there are in the area. We will work with two different APIs during this challenge:
#
# - Foursquare API
# - Visual Crossing API
#
# We will try to find correlations between the severity of crash and weather/number of bars in the area. To indicate the severity of a crash, we will use column `Injury Type`.

# %% [markdown]
# ## Data
#
# The data for this exercise can be found [here](https://drive.google.com/file/d/1_KF9oIJV8cB8i3ngA4JPOLWIE_ETE6CJ/view?usp=sharing).
#
# Just run the cells below to get your data ready. Little help from us.

# %%
import pandas as pd
import os
pd.set_option("display.max_columns", None)

# %% [markdown]
# ### Data Preparation
#
# Tasks:
# - load the data in Pandas DataFrame
# - drop the columns where latitude or longitude is missing
# - drop the columns where latitude and longitude are 0.0
# - create column `ll` that contains concatenated strings of latitude and longitude

# %%
df = pd.read_csv("monroe-county-crash-data2003-to-2015.csv", encoding= 'unicode_escape')
df.head(10)
# Out:
#    Master Record Number  Year  Month  Day Weekend?    Hour Collision Type  \
# 0             902363382  2015      1    5  Weekday     0.0          2-Car
# 1             902364268  2015      1    6  Weekday  1500.0          2-Car
# 2             902364412  2015      1    6  Weekend  2300.0          2-Car
# 3             902364551  2015      1    7  Weekend   900.0          2-Car
# 4             902364615  2015      1    7  Weekend  1100.0          2-Car
# 5             902364664  2015      1    6  Weekday  1800.0          2-Car
# 6             902364682  2015      1    6  Weekday  1200.0          2-Car
# 7             902364683  2015      1    6  Weekday  1400.0          1-Car
# 8             902364714  2015      1    7  Weekend  1400.0          2-Car
# 9             902364756  2015      1    7  Weekend  1600.0          1-Car
#
#           Injury Type                            Primary Factor  \
# 0   No injury/unknown     OTHER (DRIVER) - EXPLAIN IN NARRATIVE
# 1   No injury/unknown                     FOLLOWING TOO CLOSELY
# 2  Non-incapacitating                 DISREGARD SIGNAL/REG SIGN
# 3  Non-incapacitating             FAILURE TO YIELD RIGHT OF WAY
# 4   No injury/unknown             FAILURE TO YIELD RIGHT OF WAY
# 5   No injury/unknown             FAILURE TO YIELD RIGHT OF WAY
# 6   No injury/unknown  DRIVER DISTRACTED - EXPLAIN IN NARRATIVE
# 7      Incapacitating               ENGINE FAILURE OR DEFECTIVE
# 8   No injury/unknown                     FOLLOWING TOO CLOSELY
# 9   No injury/unknown                        RAN OFF ROAD RIGHT
#
#          Reported_Location   Latitude  Longitude
# 0               1ST & FESS  39.159207 -86.525874
# 1            2ND & COLLEGE  39.161440 -86.534848
# 2    BASSWOOD & BLOOMFIELD  39.149780 -86.568890
# 3           GATES & JACOBS  39.165655 -86.575956
# 4                    W 3RD  39.164848 -86.579625
# 5           BURKS & WALNUT  39.126670 -86.531370
# 6  SOUTH CURRY PIKE LOT 71  39.150825 -86.584899
# 7          NORTH LOUDEN RD  39.199272 -86.637024
# 8          LIBERTY & W 3RD  39.164610 -86.579130
# 9        PATTERSON & W 3RD  39.163440 -86.551280

# %%
df.shape
# Out:
# (53943, 12)

# %%
df.dtypes
# Out:
# Master Record Number      int64
# Year                      int64
# Month                     int64
# Day                       int64
# Weekend?                 object
# Hour                    float64
# Collision Type           object
# Injury Type              object
# Primary Factor           object
# Reported_Location        object
# Latitude                float64
# Longitude               float64
# dtype: object

# %%
df2 = df.dropna(subset=['Latitude', 'Longitude'])
df2.head(10)
# Out:
#    Master Record Number  Year  Month  Day Weekend?    Hour Collision Type  \
# 0             902363382  2015      1    5  Weekday     0.0          2-Car
# 1             902364268  2015      1    6  Weekday  1500.0          2-Car
# 2             902364412  2015      1    6  Weekend  2300.0          2-Car
# 3             902364551  2015      1    7  Weekend   900.0          2-Car
# 4             902364615  2015      1    7  Weekend  1100.0          2-Car
# 5             902364664  2015      1    6  Weekday  1800.0          2-Car
# 6             902364682  2015      1    6  Weekday  1200.0          2-Car
# 7             902364683  2015      1    6  Weekday  1400.0          1-Car
# 8             902364714  2015      1    7  Weekend  1400.0          2-Car
# 9             902364756  2015      1    7  Weekend  1600.0          1-Car
#
#           Injury Type                            Primary Factor  \
# 0   No injury/unknown     OTHER (DRIVER) - EXPLAIN IN NARRATIVE
# 1   No injury/unknown                     FOLLOWING TOO CLOSELY
# 2  Non-incapacitating                 DISREGARD SIGNAL/REG SIGN
# 3  Non-incapacitating             FAILURE TO YIELD RIGHT OF WAY
# 4   No injury/unknown             FAILURE TO YIELD RIGHT OF WAY
# 5   No injury/unknown             FAILURE TO YIELD RIGHT OF WAY
# 6   No injury/unknown  DRIVER DISTRACTED - EXPLAIN IN NARRATIVE
# 7      Incapacitating               ENGINE FAILURE OR DEFECTIVE
# 8   No injury/unknown                     FOLLOWING TOO CLOSELY
# 9   No injury/unknown                        RAN OFF ROAD RIGHT
#
#          Reported_Location   Latitude  Longitude
# 0               1ST & FESS  39.159207 -86.525874
# 1            2ND & COLLEGE  39.161440 -86.534848
# 2    BASSWOOD & BLOOMFIELD  39.149780 -86.568890
# 3           GATES & JACOBS  39.165655 -86.575956
# 4                    W 3RD  39.164848 -86.579625
# 5           BURKS & WALNUT  39.126670 -86.531370
# 6  SOUTH CURRY PIKE LOT 71  39.150825 -86.584899
# 7          NORTH LOUDEN RD  39.199272 -86.637024
# 8          LIBERTY & W 3RD  39.164610 -86.579130
# 9        PATTERSON & W 3RD  39.163440 -86.551280

# %%
df2.shape
# Out:
# (53913, 12)

# %%
# Here we are removing the columns where latitude and longitude are 0.0.

df3 = df2[(df2["Latitude"] != 0) | (df2["Longitude"] != 0)] # | represents Boolean OR.
df3.shape
# Out:
# (49005, 12)

# %%
df3.head(10)
# Out:
#    Master Record Number  Year  Month  Day Weekend?    Hour Collision Type  \
# 0             902363382  2015      1    5  Weekday     0.0          2-Car
# 1             902364268  2015      1    6  Weekday  1500.0          2-Car
# 2             902364412  2015      1    6  Weekend  2300.0          2-Car
# 3             902364551  2015      1    7  Weekend   900.0          2-Car
# 4             902364615  2015      1    7  Weekend  1100.0          2-Car
# 5             902364664  2015      1    6  Weekday  1800.0          2-Car
# 6             902364682  2015      1    6  Weekday  1200.0          2-Car
# 7             902364683  2015      1    6  Weekday  1400.0          1-Car
# 8             902364714  2015      1    7  Weekend  1400.0          2-Car
# 9             902364756  2015      1    7  Weekend  1600.0          1-Car
#
#           Injury Type                            Primary Factor  \
# 0   No injury/unknown     OTHER (DRIVER) - EXPLAIN IN NARRATIVE
# 1   No injury/unknown                     FOLLOWING TOO CLOSELY
# 2  Non-incapacitating                 DISREGARD SIGNAL/REG SIGN
# 3  Non-incapacitating             FAILURE TO YIELD RIGHT OF WAY
# 4   No injury/unknown             FAILURE TO YIELD RIGHT OF WAY
# 5   No injury/unknown             FAILURE TO YIELD RIGHT OF WAY
# 6   No injury/unknown  DRIVER DISTRACTED - EXPLAIN IN NARRATIVE
# 7      Incapacitating               ENGINE FAILURE OR DEFECTIVE
# 8   No injury/unknown                     FOLLOWING TOO CLOSELY
# 9   No injury/unknown                        RAN OFF ROAD RIGHT
#
#          Reported_Location   Latitude  Longitude
# 0               1ST & FESS  39.159207 -86.525874
# 1            2ND & COLLEGE  39.161440 -86.534848
# 2    BASSWOOD & BLOOMFIELD  39.149780 -86.568890
# 3           GATES & JACOBS  39.165655 -86.575956
# 4                    W 3RD  39.164848 -86.579625
# 5           BURKS & WALNUT  39.126670 -86.531370
# 6  SOUTH CURRY PIKE LOT 71  39.150825 -86.584899
# 7          NORTH LOUDEN RD  39.199272 -86.637024
# 8          LIBERTY & W 3RD  39.164610 -86.579130
# 9        PATTERSON & W 3RD  39.163440 -86.551280

# %%
df3['ll'] = df3["Latitude"].astype(str) + "," + df3["Longitude"].astype(str)
df3.head(10)
# Out:
# <ipython-input-9-59741f85b233>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['ll'] = df3["Latitude"].astype(str) + "," + df3["Longitude"].astype(str)
#    Master Record Number  Year  Month  Day Weekend?    Hour Collision Type  \
# 0             902363382  2015      1    5  Weekday     0.0          2-Car
# 1             902364268  2015      1    6  Weekday  1500.0          2-Car
# 2             902364412  2015      1    6  Weekend  2300.0          2-Car
# 3             902364551  2015      1    7  Weekend   900.0          2-Car
# 4             902364615  2015      1    7  Weekend  1100.0          2-Car
# 5             902364664  2015      1    6  Weekday  1800.0          2-Car
# 6             902364682  2015      1    6  Weekday  1200.0          2-Car
# 7             902364683  2015      1    6  Weekday  1400.0          1-Car
# 8             902364714  2015      1    7  Weekend  1400.0          2-Car
# 9             902364756  2015      1    7  Weekend  1600.0          1-Car
#
#           Injury Type                            Primary Factor  \
# 0   No injury/unknown     OTHER (DRIVER) - EXPLAIN IN NARRATIVE
# 1   No injury/unknown                     FOLLOWING TOO CLOSELY
# 2  Non-incapacitating                 DISREGARD SIGNAL/REG SIGN
# 3  Non-incapacitating             FAILURE TO YIELD RIGHT OF WAY
# 4   No injury/unknown             FAILURE TO YIELD RIGHT OF WAY
# 5   No injury/unknown             FAILURE TO YIELD RIGHT OF WAY
# 6   No injury/unknown  DRIVER DISTRACTED - EXPLAIN IN NARRATIVE
# 7      Incapacitating               ENGINE FAILURE OR DEFECTIVE
# 8   No injury/unknown                     FOLLOWING TOO CLOSELY
# 9   No injury/unknown                        RAN OFF ROAD RIGHT
#
#          Reported_Location   Latitude  Longitude                        ll
# 0               1ST & FESS  39.159207 -86.525874  39.15920668,-86.52587356
# 1            2ND & COLLEGE  39.161440 -86.534848       39.16144,-86.534848
# 2    BASSWOOD & BLOOMFIELD  39.149780 -86.568890  39.14978027,-86.56889006
# 3           GATES & JACOBS  39.165655 -86.575956    39.165655,-86.57595635
# 4                    W 3RD  39.164848 -86.579625    39.164848,-86.57962482
# 5           BURKS & WALNUT  39.126670 -86.531370  39.12666969,-86.53136998
# 6  SOUTH CURRY PIKE LOT 71  39.150825 -86.584899      39.150825,-86.584899
# 7          NORTH LOUDEN RD  39.199272 -86.637024  39.19927216,-86.63702393
# 8          LIBERTY & W 3RD  39.164610 -86.579130  39.16461021,-86.57913007
# 9        PATTERSON & W 3RD  39.163440 -86.551280  39.16344009,-86.55128002

# %%
df3.shape
# Out:
# (49005, 13)

# %%
df3.dtypes
# Out:
# Master Record Number      int64
# Year                      int64
# Month                     int64
# Day                       int64
# Weekend?                 object
# Hour                    float64
# Collision Type           object
# Injury Type              object
# Primary Factor           object
# Reported_Location        object
# Latitude                float64
# Longitude               float64
# ll                       object
# dtype: object

# %%
df3["Injury Type"].value_counts()
# Out:
# No injury/unknown     37467
# Non-incapacitating    10427
# Incapacitating         1003
# Fatal                   108
# Name: Injury Type, dtype: int64

# %%
len(df3['ll'].value_counts())
# Out:
# 19397

# %%
df3['ll'].value_counts().head(10)
# Out:
# 39.16424,-86.4984                279
# 39.164752,-86.573104             275
# 39.148144,-86.572992             232
# 39.125312,-86.610496             216
# 39.186368,-86.5344               211
# 39.164640000000006,-86.5324      188
# 39.176544,-86.5624               187
# 39.164640000000006,-86.534816    178
# 39.186544,-86.537888             176
# 39.16424,-86.492944              176
# Name: ll, dtype: int64

# %%
df3['ll'].value_counts().tail(10)
# Out:
# 39.15642963,-86.40841206           1
# 39.17175546,-86.5324               1
# 39.164590000000004,-86.57617403    1
# 39.16421928,-86.50195219           1
# 39.14663118,-86.516192             1
# 39.12578993,-86.51912972           1
# 39.21509467,-86.59272356           1
# 39.151184,-86.49629200000001       1
# 39.24064407,-86.43734756           1
# 39.15565327,-86.49772              1
# Name: ll, dtype: int64

# %%
# We will create a new column called "Injury Type Value" which is just converting the "Injury Type" column into a numerical column.
# This new column will be easier to work with.
 
df3["Injury Type Value"] = df3["Injury Type"].replace({"No injury/unknown": 0,
                                                      "Non-incapacitating": 1,
                                                      "Incapacitating": 2,
                                                      "Fatal": 3})
# Out:
# <ipython-input-16-a7db029a63d9>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3["Injury Type Value"] = df3["Injury Type"].replace({"No injury/unknown": 0,

# %%
df3.head()
# Out:
#    Master Record Number  Year  Month  Day Weekend?    Hour Collision Type  \
# 0             902363382  2015      1    5  Weekday     0.0          2-Car
# 1             902364268  2015      1    6  Weekday  1500.0          2-Car
# 2             902364412  2015      1    6  Weekend  2300.0          2-Car
# 3             902364551  2015      1    7  Weekend   900.0          2-Car
# 4             902364615  2015      1    7  Weekend  1100.0          2-Car
#
#           Injury Type                         Primary Factor  \
# 0   No injury/unknown  OTHER (DRIVER) - EXPLAIN IN NARRATIVE
# 1   No injury/unknown                  FOLLOWING TOO CLOSELY
# 2  Non-incapacitating              DISREGARD SIGNAL/REG SIGN
# 3  Non-incapacitating          FAILURE TO YIELD RIGHT OF WAY
# 4   No injury/unknown          FAILURE TO YIELD RIGHT OF WAY
#
#        Reported_Location   Latitude  Longitude                        ll  \
# 0             1ST & FESS  39.159207 -86.525874  39.15920668,-86.52587356
# 1          2ND & COLLEGE  39.161440 -86.534848       39.16144,-86.534848
# 2  BASSWOOD & BLOOMFIELD  39.149780 -86.568890  39.14978027,-86.56889006
# 3         GATES & JACOBS  39.165655 -86.575956    39.165655,-86.57595635
# 4                  W 3RD  39.164848 -86.579625    39.164848,-86.57962482
#
#    Injury Type Value
# 0                  0
# 1                  0
# 2                  1
# 3                  1
# 4                  0

# %%
df3.shape
# Out:
# (49005, 14)

# %%
df3.dtypes
# Out:
# Master Record Number      int64
# Year                      int64
# Month                     int64
# Day                       int64
# Weekend?                 object
# Hour                    float64
# Collision Type           object
# Injury Type              object
# Primary Factor           object
# Reported_Location        object
# Latitude                float64
# Longitude               float64
# ll                       object
# Injury Type Value         int64
# dtype: object

# %% [markdown]
# # Foursquare API
#
# Foursquare API documentation is [here](https://developer.foursquare.com/)
#
# 1. Start a foursquare application and get your keys.
# 2. For each crash, create the function **get_venues** that will pull bars in the radius of 5km around the crash
#
# #### example
# `get_venues('48.146394, 17.107969')`
#
# 3. Find a relationship (if there is any) between number of bars in the area and severity of the crash.
#
# HINTs:
# - check out python package "foursquare" (no need to send HTTP requests directly with library `requests`)
# - **categoryId** for bars and nightlife needs to be found in the [foursquare API documentation](https://developer.foursquare.com/docs/api-reference/venues/search/)

# %%
import foursquare

# %%
#set the keys
foursquare_id = os.environ["FOURSQUARE_API_ID"]
foursquare_secret = os.environ["FOURSQUARE_API_SECRET"]

# Set the versioning parameter.

v = "20200731"

# %%
client = foursquare.Foursquare(client_id=foursquare_id, client_secret=foursquare_secret, version=v)

# %%
# To find the bars, we will use the categoryID for nightlife spots.

def get_venues(coords):
    """Returns a response from an HTTP request which contains information about the bars in a 5 km radius of the input coordinates."""

    response = client.venues.search(
        params={'ll': coords, 'radius': 5000, "query": "bar", 
                "categoryId": "4d4b7105d754a06376d81259"})
    return response

# %%
coords_1 = df3['ll'].iloc[0]
print(coords_1)
# Out:
# 39.15920668,-86.52587356

# %%
practice = get_venues(coords_1)
practice
# Out:
# {'venues': [{'id': '4aea47d8f964a520bbba21e3',
#    'name': "Kilroy's Bar & Grill",
#    'location': {'address': '502 E Kirkwood Ave',
#     'lat': 39.16647162279348,
#     'lng': -86.52808720706821,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 39.16647162279348,
#       'lng': -86.52808720706821},
#      {'label': 'entrance', 'lat': 39.166417, 'lng': -86.528033}],
#     'distance': 830,
#     'postalCode': '47408',
#     'cc': 'US',
#     'city': 'Bloomington',
#     'state': 'IN',
#     'country': 'United States',
#     'formattedAddress': ['502 E Kirkwood Ave',
#      'Bloomington, IN 47408',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d116941735',
#      'name': 'Bar',
#      'pluralName': 'Bars',
#      'shortName': 'Bar',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#       'suffix': '.png'},
#      'primary': True}],
#    'venuePage': {'id': '54966015'},
#    'referralId': 'v-1605809190',
#    'hasPerk': False},
#   {'id': '4b074185f964a520ccfa22e3',
#    'name': 'Brothers Bar & Grill',
#    'location': {'address': '215 N Walnut St',
#     'crossStreet': 'at W 7th St',
#     'lat': 39.16824984162702,
#     'lng': -86.53380116596085,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 39.16824984162702,
#       'lng': -86.53380116596085}],
#     'distance': 1217,
#     'postalCode': '47404',
#     'cc': 'US',
#     'city': 'Bloomington',
#     'state': 'IN',
#     'country': 'United States',
#     'formattedAddress': ['215 N Walnut St (at W 7th St)',
#      'Bloomington, IN 47404',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d116941735',
#      'name': 'Bar',
#      'pluralName': 'Bars',
#      'shortName': 'Bar',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#       'suffix': '.png'},
#      'primary': True}],
#    'delivery': {'id': '2147342',
#     'url': 'https://www.grubhub.com/restaurant/brothers-bar-and-grill-215-north-walnut-street-bloomington/2147342?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2147342',
#     'provider': {'name': 'grubhub',
#      'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#       'sizes': [40, 50],
#       'name': '/delivery_provider_grubhub_20180129.png'}}},
#    'referralId': 'v-1605809190',
#    'hasPerk': False},
#   {'id': '4b54ccc0f964a52007cd27e3',
#    'name': 'Coaches Bar & Grill Bloomington',
#    'location': {'address': '245 N College Ave',
#     'lat': 39.168271059024775,
#     'lng': -86.53508216142654,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 39.168271059024775,
#       'lng': -86.53508216142654},
#      {'label': 'entrance', 'lat': 39.168282, 'lng': -86.535009}],
#     'distance': 1284,
#     'postalCode': '47404',
#     'cc': 'US',
#     'city': 'Bloomington',
#     'state': 'IN',
#     'country': 'United States',
#     'formattedAddress': ['245 N College Ave',
#      'Bloomington, IN 47404',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d116941735',
#      'name': 'Bar',
#      'pluralName': 'Bars',
#      'shortName': 'Bar',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#       'suffix': '.png'},
#      'primary': True}],
#    'referralId': 'v-1605809190',
#    'hasPerk': False},
#   {'id': '4b1958c4f964a520a4db23e3',
#    'name': "Kilroy's Bar & Grill: Sports Bar",
#    'location': {'address': '319 N Walnut St',
#     'lat': 39.16914893762117,
#     'lng': -86.53376389086642,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 39.16914893762117,
#       'lng': -86.53376389086642}],
#     'distance': 1299,
#     'postalCode': '47404',
#     'cc': 'US',
#     'city': 'Bloomington',
#     'state': 'IN',
#     'country': 'United States',
#     'formattedAddress': ['319 N Walnut St',
#      'Bloomington, IN 47404',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d116941735',
#      'name': 'Bar',
#      'pluralName': 'Bars',
#      'shortName': 'Bar',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#       'suffix': '.png'},
#      'primary': True}],
#    'delivery': {'id': '2160374',
#     'url': 'https://www.grubhub.com/restaurant/kilroys-sports-bar-319-north-walnut-street-bloomington/2160374?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2160374',
#     'provider': {'name': 'grubhub',
#      'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#       'sizes': [40, 50],
#       'name': '/delivery_provider_grubhub_20180129.png'}}},
#    'venuePage': {'id': '35870367'},
#    'referralId': 'v-1605809190',
#    'hasPerk': False},
#   {'id': '4b1ef579f964a5201f2224e3',
#    'name': "Applebee's Grill + Bar",
#    'location': {'address': '2894 E 3rd St',
#     'lat': 39.16200256566383,
#     'lng': -86.49674052907376,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 39.16200256566383,
#       'lng': -86.49674052907376}],
#     'distance': 2533,
#     'postalCode': '47401',
#     'cc': 'US',
#     'city': 'Bloomington',
#     'state': 'IN',
#     'country': 'United States',
#     'formattedAddress': ['2894 E 3rd St',
#      'Bloomington, IN 47401',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d14e941735',
#      'name': 'American Restaurant',
#      'pluralName': 'American Restaurants',
#      'shortName': 'American',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'},
#      'primary': True}],
#    'delivery': {'id': '976930',
#     'url': 'https://www.grubhub.com/restaurant/applebees-grill--bar-2800-e-3rd-st-bloomington/976930?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=976930',
#     'provider': {'name': 'grubhub',
#      'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#       'sizes': [40, 50],
#       'name': '/delivery_provider_grubhub_20180129.png'}}},
#    'referralId': 'v-1605809190',
#    'hasPerk': False},
#   {'id': '4b9adfc8f964a52065de35e3',
#    'name': '56 Degrees Bar',
#    'location': {'address': '1131 S College Mall Rd',
#     'crossStreet': 'at Covenanter Dr',
#     'lat': 39.154388427734375,
#     'lng': -86.4966812133789,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 39.154388427734375,
#       'lng': -86.4966812133789}],
#     'distance': 2576,
#     'postalCode': '47401',
#     'cc': 'US',
#     'city': 'Bloomington',
#     'state': 'IN',
#     'country': 'United States',
#     'formattedAddress': ['1131 S College Mall Rd (at Covenanter Dr)',
#      'Bloomington, IN 47401',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d116941735',
#      'name': 'Bar',
#      'pluralName': 'Bars',
#      'shortName': 'Bar',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#       'suffix': '.png'},
#      'primary': True}],
#    'referralId': 'v-1605809190',
#    'hasPerk': False},
#   {'id': '5dc5f6ec82b9e900078e9b6a',
#    'name': 'Yogi’s Bar & Grill',
#    'location': {'address': '302 N Walnut St',
#     'lat': 39.16861,
#     'lng': -86.533404,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 39.16861,
#       'lng': -86.533404},
#      {'label': 'entrance', 'lat': 39.168952, 'lng': -86.533441}],
#     'distance': 1232,
#     'postalCode': '47404',
#     'cc': 'US',
#     'city': 'Bloomington',
#     'state': 'IN',
#     'country': 'United States',
#     'formattedAddress': ['302 N Walnut St',
#      'Bloomington, IN 47404',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d11d941735',
#      'name': 'Sports Bar',
#      'pluralName': 'Sports Bars',
#      'shortName': 'Sports Bar',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/sportsbar_',
#       'suffix': '.png'},
#      'primary': True}],
#    'delivery': {'id': '1858214',
#     'url': 'https://www.grubhub.com/restaurant/yogis-bar--grill-302-north-walnut-street-bloomington/1858214?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1858214',
#     'provider': {'name': 'grubhub',
#      'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#       'sizes': [40, 50],
#       'name': '/delivery_provider_grubhub_20180129.png'}}},
#    'referralId': 'v-1605809190',
#    'hasPerk': False},
#   {'id': '522293d111d20e5a982b5064',
#    'name': 'The Moontower Bar and Grill',
#    'location': {'address': '3342 S Dawson Ln',
#     'lat': 39.127233000000004,
#     'lng': -86.555251,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 39.127233000000004,
#       'lng': -86.555251},
#      {'label': 'entrance', 'lat': 39.127315, 'lng': -86.555248}],
#     'distance': 4370,
#     'postalCode': '47403',
#     'cc': 'US',
#     'city': 'Bloomington',
#     'state': 'IN',
#     'country': 'United States',
#     'formattedAddress': ['3342 S Dawson Ln',
#      'Bloomington, IN 47403',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d116941735',
#      'name': 'Bar',
#      'pluralName': 'Bars',
#      'shortName': 'Bar',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#       'suffix': '.png'},
#      'primary': True}],
#    'referralId': 'v-1605809190',
#    'hasPerk': False},
#   {'id': '4e02625fd164b56ad530e036',
#    'name': '3 College Girls Martini Bar',
#    'location': {'address': '718',
#     'lat': 39.17351175,
#     'lng': -86.5275729,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 39.17351175,
#       'lng': -86.5275729}],
#     'distance': 1599,
#     'postalCode': '47408',
#     'cc': 'US',
#     'city': 'Bloomington',
#     'state': 'IN',
#     'country': 'United States',
#     'formattedAddress': ['718', 'Bloomington, IN 47408', 'United States']},
#    'categories': [{'id': '4bf58dd8d48988d11e941735',
#      'name': 'Cocktail Bar',
#      'pluralName': 'Cocktail Bars',
#      'shortName': 'Cocktail',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/cocktails_',
#       'suffix': '.png'},
#      'primary': True}],
#    'referralId': 'v-1605809190',
#    'hasPerk': False},
#   {'id': '5f495b448e72256f3db2d45e',
#    'name': 'The Bar Shack',
#    'location': {'lat': 39.13650990250943,
#     'lng': -86.55430018901825,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 39.13650990250943,
#       'lng': -86.55430018901825}],
#     'distance': 3522,
#     'cc': 'US',
#     'city': 'Bloomington',
#     'state': 'IN',
#     'country': 'United States',
#     'formattedAddress': ['Bloomington, IN', 'United States']},
#    'categories': [{'id': '4bf58dd8d48988d116941735',
#      'name': 'Bar',
#      'pluralName': 'Bars',
#      'shortName': 'Bar',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#       'suffix': '.png'},
#      'primary': True}],
#    'referralId': 'v-1605809190',
#    'hasPerk': False},
#   {'id': '4d0c24f75c46a09330e806b4',
#    'name': 'Skid Row Bar And Grill',
#    'location': {'lat': 39.16778639,
#     'lng': -86.50508517,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 39.16778639,
#       'lng': -86.50508517}],
#     'distance': 2032,
#     'postalCode': '47408',
#     'cc': 'US',
#     'city': 'Spencer',
#     'state': 'IN',
#     'country': 'United States',
#     'formattedAddress': ['Spencer, IN 47408', 'United States']},
#    'categories': [{'id': '4bf58dd8d48988d116941735',
#      'name': 'Bar',
#      'pluralName': 'Bars',
#      'shortName': 'Bar',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#       'suffix': '.png'},
#      'primary': True}],
#    'referralId': 'v-1605809190',
#    'hasPerk': False},
#   {'id': '4ff8aa2fe4b0734a7b4b3e23',
#    'name': 'Back Bar',
#    'location': {'lat': 39.181871,
#     'lng': -86.525607,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 39.181871,
#       'lng': -86.525607}],
#     'distance': 2523,
#     'postalCode': '47408',
#     'cc': 'US',
#     'city': 'Bloomington',
#     'state': 'IN',
#     'country': 'United States',
#     'formattedAddress': ['Bloomington, IN 47408', 'United States']},
#    'categories': [{'id': '4bf58dd8d48988d11e941735',
#      'name': 'Cocktail Bar',
#      'pluralName': 'Cocktail Bars',
#      'shortName': 'Cocktail',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/cocktails_',
#       'suffix': '.png'},
#      'primary': True}],
#    'referralId': 'v-1605809190',
#    'hasPerk': False},
#   {'id': '4b0c6c73f964a520ee3c23e3',
#    'name': "Chili's Grill & Bar",
#    'location': {'address': '2811 East 3rd Street',
#     'lat': 39.1646961,
#     'lng': -86.4957458,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 39.1646961,
#       'lng': -86.4957458}],
#     'distance': 2671,
#     'postalCode': '47401',
#     'cc': 'US',
#     'city': 'Bloomington',
#     'state': 'IN',
#     'country': 'United States',
#     'formattedAddress': ['2811 East 3rd Street',
#      'Bloomington, IN 47401',
#      'United States']},
#    'categories': [{'id': '56aa371ae4b08b9a8d5734ba',
#      'name': 'Tex-Mex Restaurant',
#      'pluralName': 'Tex-Mex Restaurants',
#      'shortName': 'Tex-Mex',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#       'suffix': '.png'},
#      'primary': True}],
#    'venuePage': {'id': '563769166'},
#    'referralId': 'v-1605809190',
#    'hasPerk': False},
#   {'id': '4aebd299f964a520e3c421e3',
#    'name': 'The Alley Bar',
#    'location': {'address': '210 W Kirkwood Ave',
#     'crossStreet': 'at College Ave',
#     'lat': 39.16658558836782,
#     'lng': -86.53528255868468,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 39.16658558836782,
#       'lng': -86.53528255868468},
#      {'label': 'entrance', 'lat': 39.166699, 'lng': -86.535255}],
#     'distance': 1155,
#     'postalCode': '47404',
#     'cc': 'US',
#     'city': 'Bloomington',
#     'state': 'IN',
#     'country': 'United States',
#     'formattedAddress': ['210 W Kirkwood Ave (at College Ave)',
#      'Bloomington, IN 47404',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d116941735',
#      'name': 'Bar',
#      'pluralName': 'Bars',
#      'shortName': 'Bar',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#       'suffix': '.png'},
#      'primary': True}],
#    'referralId': 'v-1605809190',
#    'hasPerk': False},
#   {'id': '5032cd8ce4b0478e593120c1',
#    'name': 'Bar at Holiday Inn',
#    'location': {'lat': 39.185773865735655,
#     'lng': -86.5365784336047,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 39.185773865735655,
#       'lng': -86.5365784336047}],
#     'distance': 3098,
#     'postalCode': '47404',
#     'cc': 'US',
#     'city': 'Bloomington',
#     'state': 'IN',
#     'country': 'United States',
#     'formattedAddress': ['Bloomington, IN 47404', 'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1d5941735',
#      'name': 'Hotel Bar',
#      'pluralName': 'Hotel Bars',
#      'shortName': 'Hotel Bar',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_bar_',
#       'suffix': '.png'},
#      'primary': True}],
#    'referralId': 'v-1605809190',
#    'hasPerk': False},
#   {'id': '53ec6cb0498e977c626b7988',
#    'name': 'Behind The Couch Bar',
#    'location': {'lat': 39.18266557506557,
#     'lng': -86.52902767313866,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 39.18266557506557,
#       'lng': -86.52902767313866}],
#     'distance': 2625,
#     'cc': 'US',
#     'city': 'Bloomington',
#     'state': 'IN',
#     'country': 'United States',
#     'formattedAddress': ['Bloomington, IN', 'United States']},
#    'categories': [{'id': '4bf58dd8d48988d116941735',
#      'name': 'Bar',
#      'pluralName': 'Bars',
#      'shortName': 'Bar',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#       'suffix': '.png'},
#      'primary': True}],
#    'referralId': 'v-1605809190',
#    'hasPerk': False},
#   {'id': '4b230eddf964a520c45224e3',
#    'name': 'Sushi Bar',
#    'location': {'address': '2522 E 10th St',
#     'lat': 39.17122742980106,
#     'lng': -86.50314945757978,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 39.17122742980106,
#       'lng': -86.50314945757978},
#      {'label': 'entrance', 'lat': 39.171296, 'lng': -86.503134}],
#     'distance': 2374,
#     'postalCode': '47408',
#     'cc': 'US',
#     'city': 'Bloomington',
#     'state': 'IN',
#     'country': 'United States',
#     'formattedAddress': ['2522 E 10th St',
#      'Bloomington, IN 47408',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1d2941735',
#      'name': 'Sushi Restaurant',
#      'pluralName': 'Sushi Restaurants',
#      'shortName': 'Sushi',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#       'suffix': '.png'},
#      'primary': True}],
#    'delivery': {'id': '2177720',
#     'url': 'https://www.grubhub.com/restaurant/sushi-bar-llc-2522-east-10th-street-bloomington/2177720?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2177720',
#     'provider': {'name': 'grubhub',
#      'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#       'sizes': [40, 50],
#       'name': '/delivery_provider_grubhub_20180129.png'}}},
#    'venuePage': {'id': '32899705'},
#    'referralId': 'v-1605809190',
#    'hasPerk': False},
#   {'id': '4e9f6c898b814d19b51e8231',
#    'name': 'Tower Bar And Grill',
#    'location': {'lat': 39.18274654349851,
#     'lng': -86.53585842362939,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 39.18274654349851,
#       'lng': -86.53585842362939}],
#     'distance': 2758,
#     'cc': 'US',
#     'state': 'Indiana',
#     'country': 'United States',
#     'formattedAddress': ['Indiana', 'United States']},
#    'categories': [{'id': '4bf58dd8d48988d116941735',
#      'name': 'Bar',
#      'pluralName': 'Bars',
#      'shortName': 'Bar',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#       'suffix': '.png'},
#      'primary': True}],
#    'referralId': 'v-1605809190',
#    'hasPerk': False},
#   {'id': '53ea4a71498e76cdafe2ee7c',
#    'name': 'C3 Bar',
#    'location': {'address': '1505 S Piazza Dr',
#     'lat': 39.149517698150184,
#     'lng': -86.49948205591643,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 39.149517698150184,
#       'lng': -86.49948205591643},
#      {'label': 'entrance', 'lat': 39.149426, 'lng': -86.49963}],
#     'distance': 2520,
#     'postalCode': '47401',
#     'cc': 'US',
#     'city': 'Bloomington',
#     'state': 'IN',
#     'country': 'United States',
#     'formattedAddress': ['1505 S Piazza Dr',
#      'Bloomington, IN 47401',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d11e941735',
#      'name': 'Cocktail Bar',
#      'pluralName': 'Cocktail Bars',
#      'shortName': 'Cocktail',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/cocktails_',
#       'suffix': '.png'},
#      'primary': True}],
#    'venuePage': {'id': '92552397'},
#    'referralId': 'v-1605809190',
#    'hasPerk': False},
#   {'id': '5136ddcfe4b0536562575bc2',
#    'name': 'V3 Bar',
#    'location': {'lat': 39.17274536266685,
#     'lng': -86.49509182228358,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 39.17274536266685,
#       'lng': -86.49509182228358}],
#     'distance': 3054,
#     'cc': 'US',
#     'city': 'Bloomington',
#     'state': 'IN',
#     'country': 'United States',
#     'formattedAddress': ['Bloomington, IN', 'United States']},
#    'categories': [{'id': '4bf58dd8d48988d116941735',
#      'name': 'Bar',
#      'pluralName': 'Bars',
#      'shortName': 'Bar',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#       'suffix': '.png'},
#      'primary': True}],
#    'referralId': 'v-1605809190',
#    'hasPerk': False},
#   {'id': '512d82fee4b04217326b6c16',
#    'name': 'Peter Pan Lobby Bar',
#    'location': {'lat': 39.166391248351324,
#     'lng': -86.57038248807882,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 39.166391248351324,
#       'lng': -86.57038248807882}],
#     'distance': 3924,
#     'postalCode': '47404',
#     'cc': 'US',
#     'city': 'Bloomington',
#     'state': 'IN',
#     'country': 'United States',
#     'formattedAddress': ['Bloomington, IN 47404', 'United States']},
#    'categories': [{'id': '4bf58dd8d48988d116941735',
#      'name': 'Bar',
#      'pluralName': 'Bars',
#      'shortName': 'Bar',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#       'suffix': '.png'},
#      'primary': True}],
#    'referralId': 'v-1605809190',
#    'hasPerk': False},
#   {'id': '5a5156e0d1a4026792d1e982',
#    'name': 'K&C’s Barleywine Bungalow on the B-Line',
#    'location': {'address': '335 S College Ave',
#     'lat': 39.163398,
#     'lng': -86.534609,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 39.163398,
#       'lng': -86.534609}],
#     'distance': 886,
#     'postalCode': '47403',
#     'cc': 'US',
#     'city': 'Bloomington',
#     'state': 'IN',
#     'country': 'United States',
#     'formattedAddress': ['335 S College Ave',
#      'Bloomington, IN 47403',
#      'United States']},
#    'categories': [{'id': '53e510b7498ebcb1801b55d4',
#      'name': 'Night Market',
#      'pluralName': 'Night Markets',
#      'shortName': 'Night Market',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/fleamarket_',
#       'suffix': '.png'},
#      'primary': True}],
#    'referralId': 'v-1605809190',
#    'hasPerk': False},
#   {'id': '4b0aa1f8f964a520cc2523e3',
#    'name': "Lennie's  (Bloomington Brewing Company)",
#    'location': {'address': '514 E Kirkwood Ave',
#     'lat': 39.17203901489846,
#     'lng': -86.51143312454224,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 39.17203901489846,
#       'lng': -86.51143312454224}],
#     'distance': 1895,
#     'postalCode': '47408',
#     'cc': 'US',
#     'city': 'Bloomington',
#     'state': 'IN',
#     'country': 'United States',
#     'formattedAddress': ['514 E Kirkwood Ave',
#      'Bloomington, IN 47408',
#      'United States']},
#    'categories': [{'id': '50327c8591d4c4b30a586d5d',
#      'name': 'Brewery',
#      'pluralName': 'Breweries',
#      'shortName': 'Brewery',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#       'suffix': '.png'},
#      'primary': True}],
#    'referralId': 'v-1605809190',
#    'hasPerk': False},
#   {'id': '4f4cf265e4b087ae22816951',
#    'name': 'Absolut Kitty Ice Bar',
#    'location': {'address': '3024 Forest Ridge Dr, Bloomington, IN 47401',
#     'lat': 39.11379314503753,
#     'lng': -86.4915725781126,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 39.11379314503753,
#       'lng': -86.4915725781126}],
#     'distance': 5859,
#     'postalCode': '47401',
#     'cc': 'US',
#     'city': 'Bloomington',
#     'state': 'IN',
#     'country': 'United States',
#     'formattedAddress': ['3024 Forest Ridge Dr, Bloomington, IN 47401',
#      'Bloomington, IN 47401',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1d4941735',
#      'name': 'Speakeasy',
#      'pluralName': 'Speakeasies',
#      'shortName': 'Speakeasy',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/secretbar_',
#       'suffix': '.png'},
#      'primary': True}],
#    'referralId': 'v-1605809190',
#    'hasPerk': False},
#   {'id': '507c2800e4b0b5e9215c9444',
#    'name': 'The Tap',
#    'location': {'address': '101 N. College Ave.',
#     'lat': 39.16665419106344,
#     'lng': -86.53516289711268,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 39.16665419106344,
#       'lng': -86.53516289711268},
#      {'label': 'entrance', 'lat': 39.166727, 'lng': -86.535019}],
#     'distance': 1153,
#     'postalCode': '47404',
#     'cc': 'US',
#     'city': 'Bloomington',
#     'state': 'IN',
#     'country': 'United States',
#     'formattedAddress': ['101 N. College Ave.',
#      'Bloomington, IN 47404',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d116941735',
#      'name': 'Bar',
#      'pluralName': 'Bars',
#      'shortName': 'Bar',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#       'suffix': '.png'},
#      'primary': True}],
#    'venuePage': {'id': '41873970'},
#    'referralId': 'v-1605809190',
#    'hasPerk': False},
#   {'id': '4f32cd9719836c91c7fc5ff0',
#    'name': "Kilroy's Sports Bar",
#    'location': {'address': '2165 S Knightridge Rd',
#     'lat': 39.139245,
#     'lng': -86.462501,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 39.139245,
#       'lng': -86.462501},
#      {'label': 'entrance', 'lat': 39.139261, 'lng': -86.463218}],
#     'distance': 5904,
#     'postalCode': '47401',
#     'cc': 'US',
#     'city': 'Bloomington',
#     'state': 'IN',
#     'country': 'United States',
#     'formattedAddress': ['2165 S Knightridge Rd',
#      'Bloomington, IN 47401',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d11d941735',
#      'name': 'Sports Bar',
#      'pluralName': 'Sports Bars',
#      'shortName': 'Sports Bar',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/sportsbar_',
#       'suffix': '.png'},
#      'primary': True}],
#    'referralId': 'v-1605809190',
#    'hasPerk': False},
#   {'id': '4c8171a7dc018cfadde2c56c',
#    'name': 'Serendipity',
#    'location': {'address': '201 S College Ave',
#     'lat': 39.16538683322792,
#     'lng': -86.53466905898989,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 39.16538683322792,
#       'lng': -86.53466905898989}],
#     'distance': 1024,
#     'postalCode': '47404',
#     'cc': 'US',
#     'city': 'Bloomington',
#     'state': 'IN',
#     'country': 'United States',
#     'formattedAddress': ['201 S College Ave',
#      'Bloomington, IN 47404',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d11e941735',
#      'name': 'Cocktail Bar',
#      'pluralName': 'Cocktail Bars',
#      'shortName': 'Cocktail',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/cocktails_',
#       'suffix': '.png'},
#      'primary': True}],
#    'delivery': {'id': '2173999',
#     'url': 'https://www.grubhub.com/restaurant/serendipity-martini-bar-201-south-college-avenue-bloomington/2173999?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2173999',
#     'provider': {'name': 'grubhub',
#      'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#       'sizes': [40, 50],
#       'name': '/delivery_provider_grubhub_20180129.png'}}},
#    'referralId': 'v-1605809190',
#    'hasPerk': False},
#   {'id': '4aff96dbf964a520a33922e3',
#    'name': 'Bluebird Nightclub',
#    'location': {'address': '216 N Walnut St',
#     'lat': 39.16814615372232,
#     'lng': -86.5333450447381,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 39.16814615372232,
#       'lng': -86.5333450447381},
#      {'label': 'entrance', 'lat': 39.168173, 'lng': -86.533449}],
#     'distance': 1185,
#     'postalCode': '47404',
#     'cc': 'US',
#     'city': 'Bloomington',
#     'state': 'IN',
#     'country': 'United States',
#     'formattedAddress': ['216 N Walnut St',
#      'Bloomington, IN 47404',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1e9931735',
#      'name': 'Rock Club',
#      'pluralName': 'Rock Clubs',
#      'shortName': 'Rock Club',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_rockclub_',
#       'suffix': '.png'},
#      'primary': True}],
#    'referralId': 'v-1605809190',
#    'hasPerk': False},
#   {'id': '4ae293c2f964a5201a8f21e3',
#    'name': 'Video Saloon',
#    'location': {'address': '105 W 7th St',
#     'crossStreet': 'at Walnut St.',
#     'lat': 39.1684120350497,
#     'lng': -86.53395587029166,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 39.1684120350497,
#       'lng': -86.53395587029166},
#      {'label': 'entrance', 'lat': 39.168448, 'lng': -86.534094}],
#     'distance': 1239,
#     'postalCode': '47404',
#     'cc': 'US',
#     'city': 'Bloomington',
#     'state': 'IN',
#     'country': 'United States',
#     'formattedAddress': ['105 W 7th St (at Walnut St.)',
#      'Bloomington, IN 47404',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d116941735',
#      'name': 'Bar',
#      'pluralName': 'Bars',
#      'shortName': 'Bar',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#       'suffix': '.png'},
#      'primary': True}],
#    'referralId': 'v-1605809190',
#    'hasPerk': False}]}

# %%
# By examining the JSON response, we can see that the number of bars can be calculated.

len(practice["venues"])
# Out:
# 29

# %%
def number_of_bars(coords):
    """Returns the number of bars in a 5 km radius of the input coordinates."""
    
    response = get_venues(coords)
    return (len(response["venues"]))

# %%
number_of_bars(coords_1)
# Out:
# 29

# %%
coords_2 = df3['ll'].value_counts().index[0]
print(coords_2)
# Out:
# 39.16424,-86.4984

# %%
number_of_bars(coords_2)
# Out:
# 28

# %%
df4 = pd.DataFrame({'ll': df3['ll'].unique()})
print(df4.head())
print(len(df4))
# Out:
#                          ll
# 0  39.15920668,-86.52587356
# 1       39.16144,-86.534848
# 2  39.14978027,-86.56889006
# 3    39.165655,-86.57595635
# 4    39.164848,-86.57962482
# 19397

# %%
# We will take a random sample of size 300 of the locations.

df_bars = df4.sample(n=300)
len(df_bars)
# Out:
# 300

# %%
df_bars.head()
# Out:
#                              ll
# 5397   39.15134698,-86.61031799
# 3780        39.13608,-86.529792
# 15373     39.136144,-86.5284764
# 126        39.079248,-86.619792
# 19122  39.14500942,-86.57779384

# %%
df_bars.nunique()
# Out:
# ll    300
# dtype: int64

# %%
df_bars['ll'].iloc[0:10].apply(number_of_bars)
# Out:
# 6244     29
# 18469    27
# 13083     4
# 13826    28
# 3363      1
# 9059      1
# 4076      1
# 7132     13
# 12245    27
# 18530    27
# Name: ll, dtype: int64

# %%
df_bars["Number of bars"] = df_bars['ll'].apply(number_of_bars)

# %% [markdown]
# On November 19, 2020 at 1:40 PM, I exceeded the call limits for the Foursquare API because I tried to make at least 8000 requests.
# If I get another chance, I will limit the number of requests to 250.

# %% [markdown]
# After receiving assistance from Socorro through Compass, she said that the daily call quota is 950. I will limit the number of requests to 300.

# %%
df_bars.head()
# Out:
#                              ll  Number of bars
# 5397   39.15134698,-86.61031799               3
# 3780        39.13608,-86.529792              29
# 15373     39.136144,-86.5284764              29
# 126        39.079248,-86.619792               0
# 19122  39.14500942,-86.57779384              19

# %%
df5 = pd.merge(df3, df_bars, on='ll')

# %%
df5.head()
# Out:
#    Master Record Number  Year  Month  Day Weekend?    Hour Collision Type  \
# 0             902370118  2015      1    6  Weekday  1200.0          2-Car
# 1             902374549  2015      1    5  Weekday   800.0          1-Car
# 2             902375928  2015      1    6  Weekday  1800.0          1-Car
# 3                502617  2003     10    2  Weekday   700.0          2-Car
# 4             902402485  2015      2    4  Weekday  1200.0          2-Car
#
#          Injury Type                 Primary Factor     Reported_Location  \
# 0  No injury/unknown  FAILURE TO YIELD RIGHT OF WAY  HENDERSON & HILLSIDE
# 1  No injury/unknown           UNSAFE LANE MOVEMENT     FOREST & KIRKWOOD
# 2  No injury/unknown             RAN OFF ROAD RIGHT     KOONTZ & W DUVALL
# 3  No injury/unknown                   UNSAFE SPEED    DUVALL & KOONTY RD
# 4  No injury/unknown                 UNSAFE BACKING        E 8TH & N FESS
#
#     Latitude  Longitude                              ll  Injury Type Value  \
# 0  39.150636 -86.527207        39.15063632,-86.52720688                  0
# 1  39.166089 -86.519626  39.16608943,-86.51962569999999                  0
# 2  39.079248 -86.619792            39.079248,-86.619792                  0
# 3  39.079248 -86.619792            39.079248,-86.619792                  0
# 4  39.169600 -86.525712              39.1696,-86.525712                  0
#
#    Number of bars
# 0              29
# 1              27
# 2               0
# 3               0
# 4              27

# %%
len(df5)
# Out:
# 683

# %%
df5["Number of bars"].value_counts().head(10)
# Out:
# 27    201
# 28    143
# 0      41
# 29     40
# 21     35
# 22     30
# 1      21
# 2      21
# 4      20
# 23     19
# Name: Number of bars, dtype: int64

# %%
df6 = df5.iloc[:, -3:]

# %%
df6.head()
# Out:
#                                ll  Injury Type Value  Number of bars
# 0        39.15063632,-86.52720688                  0              29
# 1  39.16608943,-86.51962569999999                  0              27
# 2            39.079248,-86.619792                  0               0
# 3            39.079248,-86.619792                  0               0
# 4              39.1696,-86.525712                  0              27

# %%
df6.groupby(["Injury Type Value", 'Number of bars']).size().head(10)
# Out:
# Injury Type Value  Number of bars
# 0                  0                 31
#                    1                 10
#                    2                 11
#                    3                  7
#                    4                 14
#                    5                  7
#                    7                  2
#                    8                  1
#                    10                 3
#                    13                 5
# dtype: int64

# %%
df6["Injury Type Value"].value_counts()
# Out:
# 0    542
# 1    123
# 2     16
# 3      2
# Name: Injury Type Value, dtype: int64

# %%
df6.corr()
# Out:
#                    Injury Type Value  Number of bars
# Injury Type Value           1.000000       -0.257495
# Number of bars             -0.257495        1.000000

# %%
df6.corr().iloc[0, 1]
# Out:
# -0.2574949702494932

# %%
f"The correlation between the number of bars in the area and severity of the crash is {df6.corr().iloc[0, 1]}."
# Out:
# 'The correlation between the number of bars in the area and severity of the crash is -0.2574949702494932.'

# %% [markdown]
# This means that there is a weak negative relationship between the number of bars in the area and severity of the crash.

# %% [markdown]
# Note that the sample size is small and is biased towards the "No injury/unknown" group.

# %% [markdown]
# We will take another sample where it is equally divided among the 4 "Injury Type Value" groups.

# %%
df_itv_0 = df3[df3["Injury Type Value"] == 0]
len(df_itv_0)
# Out:
# 37467

# %%
df_itv_0_sample = df_itv_0.sample(n=75)
len(df_itv_0_sample)
# Out:
# 75

# %%
df_itv_1 = df3[df3["Injury Type Value"] == 1]
len(df_itv_1)
# Out:
# 10427

# %%
df_itv_1_sample = df_itv_1.sample(n=75)
len(df_itv_1_sample)
# Out:
# 75

# %%
df_itv_2 = df3[df3["Injury Type Value"] == 2]
len(df_itv_2)
# Out:
# 1003

# %%
df_itv_2_sample = df_itv_2.sample(n=75)
len(df_itv_2_sample)
# Out:
# 75

# %%
df_itv_3 = df3[df3["Injury Type Value"] == 3]
len(df_itv_3)
# Out:
# 108

# %%
df_itv_3_sample = df_itv_3.sample(n=75)
len(df_itv_3_sample)
# Out:
# 75

# %%
pieces = [df_itv_0_sample, df_itv_1_sample, df_itv_2_sample, df_itv_3_sample]
df_sample = pd.concat(pieces)

# %%
df_sample.head()
# Out:
#        Master Record Number  Year  Month  Day Weekend?    Hour Collision Type  \
# 47492               1580362  2004     11    5  Weekday  1200.0          2-Car
# 47632               1934051  2004     12    7  Weekend  1500.0          2-Car
# 42482               1836456  2005      1    3  Weekday  1500.0          2-Car
# 1047              902416939  2015      3    1  Weekend   200.0          1-Car
# 24356             901482224  2010      8    4  Weekday  1100.0          1-Car
#
#              Injury Type                         Primary Factor  \
# 47492  No injury/unknown                       IMPROPER PASSING
# 47632  No injury/unknown              DISREGARD SIGNAL/REG SIGN
# 42482  No injury/unknown          FAILURE TO YIELD RIGHT OF WAY
# 1047   No injury/unknown                     RAN OFF ROAD RIGHT
# 24356  No injury/unknown  OTHER (DRIVER) - EXPLAIN IN NARRATIVE
#
#             Reported_Location   Latitude  Longitude  \
# 47492     3RD ST & BALLANTINE  39.164240 -86.518921
# 47632  ATWATER ST & HENDERSON  39.163344 -86.527200
# 42482            7TH & MORTON  39.168672 -86.536000
# 1047                    SR46W  39.197824 -86.573989
# 24356       VALLEY MISSION RD  39.008304 -86.507552
#
#                                   ll  Injury Type Value
# 47492          39.16424,-86.51892108                  0
# 47632             39.163344,-86.5272                  0
# 42482     39.168671999999994,-86.536                  0
# 1047        39.19782378,-86.57398881                  0
# 24356  39.008303999999995,-86.507552                  0

# %%
df_sample["Injury Type Value"].value_counts()
# Out:
# 3    75
# 2    75
# 1    75
# 0    75
# Name: Injury Type Value, dtype: int64

# %%
df_sample["Number of bars"] = df_sample['ll'].apply(number_of_bars)

# %%
df_sample.head()
# Out:
#        Master Record Number  Year  Month  Day Weekend?    Hour Collision Type  \
# 47492               1580362  2004     11    5  Weekday  1200.0          2-Car
# 47632               1934051  2004     12    7  Weekend  1500.0          2-Car
# 42482               1836456  2005      1    3  Weekday  1500.0          2-Car
# 1047              902416939  2015      3    1  Weekend   200.0          1-Car
# 24356             901482224  2010      8    4  Weekday  1100.0          1-Car
#
#              Injury Type                         Primary Factor  \
# 47492  No injury/unknown                       IMPROPER PASSING
# 47632  No injury/unknown              DISREGARD SIGNAL/REG SIGN
# 42482  No injury/unknown          FAILURE TO YIELD RIGHT OF WAY
# 1047   No injury/unknown                     RAN OFF ROAD RIGHT
# 24356  No injury/unknown  OTHER (DRIVER) - EXPLAIN IN NARRATIVE
#
#             Reported_Location   Latitude  Longitude  \
# 47492     3RD ST & BALLANTINE  39.164240 -86.518921
# 47632  ATWATER ST & HENDERSON  39.163344 -86.527200
# 42482            7TH & MORTON  39.168672 -86.536000
# 1047                    SR46W  39.197824 -86.573989
# 24356       VALLEY MISSION RD  39.008304 -86.507552
#
#                                   ll  Injury Type Value  Number of bars
# 47492          39.16424,-86.51892108                  0              28
# 47632             39.163344,-86.5272                  0              27
# 42482     39.168671999999994,-86.536                  0              27
# 1047        39.19782378,-86.57398881                  0              21
# 24356  39.008303999999995,-86.507552                  0               2

# %%
df_sample_2 = df_sample.iloc[:, -3:]
df_sample_2.head()
# Out:
#                                   ll  Injury Type Value  Number of bars
# 47492          39.16424,-86.51892108                  0              28
# 47632             39.163344,-86.5272                  0              27
# 42482     39.168671999999994,-86.536                  0              27
# 1047        39.19782378,-86.57398881                  0              21
# 24356  39.008303999999995,-86.507552                  0               2

# %%
df_sample_2.corr()
# Out:
#                    Injury Type Value  Number of bars
# Injury Type Value           1.000000       -0.334923
# Number of bars             -0.334923        1.000000

# %%
df_sample_2.corr().iloc[0, 1]
# Out:
# -0.334922646902454

# %%
f"The correlation between the number of bars in the area and severity of the crash is {df_sample_2.corr().iloc[0, 1]}."
# Out:
# 'The correlation between the number of bars in the area and severity of the crash is -0.334922646902454.'

# %% [markdown]
# This means that there is a moderate negative relationship between the number of bars in the area and severity of the crash.

# %% [markdown]
# On November 23, 2020, I spoke to the mentor Arunabh Singh to discuss this question and he said the following.
#
# "There is no correlation between number of bars and the intensity of accident.  This is because if someone is drunk driving he just needs to hit once and it can be critical. It does not need to be correlated to many bars in the area.
# The mean,median are similar or unrelated for severity of crash.
#
# question 3 states
#
# Find a relationship (if there is any) between number of bars in the area and severity of the crash
#
# so there isnt any relationship

# %% [markdown]
# On November 24, 2020, I spoke to Arunabh Singh about the problem again.  He used df5.groupby["Injury Type Value"]["Number of bars"].mean() (or median).  When he did this, for the first 3 Injury Type Values, the mean/median was about 26 and for Injury Type Value "3", it was about 5.  I was getting a negative correlation because for the highest "Injury Type Value", the mean/median was very low.

# %% [markdown]
# We will take a random sample of size 500 of the locations.

# %%
df_bars2 = df4.sample(n=500)
len(df_bars2)
# Out:
# 500

# %%
df_bars2.head()
# Out:
#                              ll
# 230         39.137088,-86.53056
# 14907        39.1645,-86.567998
# 3666   39.14654277,-86.53242392
# 1877   39.16249847,-86.58585357
# 18295    39.211104,-86.62055369

# %%
df_bars2.nunique()
# Out:
# ll    500
# dtype: int64

# %%
df_bars2["Number of bars"] = df_bars2['ll'].apply(number_of_bars)

# %%
df_bars2.head()
# Out:
#                              ll  Number of bars
# 230         39.137088,-86.53056              29
# 14907        39.1645,-86.567998              22
# 3666   39.14654277,-86.53242392              29
# 1877   39.16249847,-86.58585357              19
# 18295    39.211104,-86.62055369               4

# %%
df7 = pd.merge(df3, df_bars2, on='ll')

# %%
df7.head()
# Out:
#    Master Record Number  Year  Month  Day Weekend?    Hour Collision Type  \
# 0             902374663  2015      1    5  Weekday  1500.0          2-Car
# 1             902404215  2015      2    7  Weekend  1100.0          2-Car
# 2             902409648  2015      3    7  Weekend  1800.0          2-Car
# 3             902383313  2015      1    5  Weekday  1000.0          2-Car
# 4             902390384  2015      2    1  Weekday  2000.0          2-Car
#
#           Injury Type                    Primary Factor   Reported_Location  \
# 0   No injury/unknown             FOLLOWING TOO CLOSELY    N WALNUT & SR46E
# 1   No injury/unknown               IMPROPER LANE USAGE  N WALNUT & SR4546W
# 2   No injury/unknown     FAILURE TO YIELD RIGHT OF WAY      SR46E & WALNUT
# 3  Non-incapacitating  ACCELERATOR FAILURE OR DEFECTIVE    N WALNUT & SR46W
# 4  Non-incapacitating             FOLLOWING TOO CLOSELY    N WALNUT & SR46E
#
#     Latitude  Longitude                  ll  Injury Type Value  Number of bars
# 0  39.186368   -86.5344  39.186368,-86.5344                  0              28
# 1  39.186368   -86.5344  39.186368,-86.5344                  0              28
# 2  39.186368   -86.5344  39.186368,-86.5344                  0              28
# 3  39.186368   -86.5344  39.186368,-86.5344                  1              28
# 4  39.186368   -86.5344  39.186368,-86.5344                  1              28

# %%
len(df7)
# Out:
# 1805

# %%
df7["Number of bars"].value_counts().head(10)
# Out:
# 28    569
# 27    522
# 29    140
# 21     88
# 25     69
# 4      62
# 0      55
# 19     36
# 22     35
# 26     34
# Name: Number of bars, dtype: int64

# %%
df7.groupby("Injury Type Value")["Number of bars"].mean()
# Out:
# Injury Type Value
# 0    23.509353
# 1    23.064767
# 2    17.875000
# 3    13.200000
# Name: Number of bars, dtype: float64

# %%
df7.groupby("Injury Type Value")["Number of bars"].median()
# Out:
# Injury Type Value
# 0    27
# 1    27
# 2    27
# 3    19
# Name: Number of bars, dtype: int64

# %%
df8 = df7.iloc[:, -3:]

# %%
df8.head()
# Out:
#                    ll  Injury Type Value  Number of bars
# 0  39.186368,-86.5344                  0              28
# 1  39.186368,-86.5344                  0              28
# 2  39.186368,-86.5344                  0              28
# 3  39.186368,-86.5344                  1              28
# 4  39.186368,-86.5344                  1              28

# %%
df8.groupby(["Injury Type Value", 'Number of bars']).size().head(10)
# Out:
# Injury Type Value  Number of bars
# 0                  0                 37
#                    1                 18
#                    2                 16
#                    3                 24
#                    4                 42
#                    5                 16
#                    6                  6
#                    7                  5
#                    8                  3
#                    9                 15
# dtype: int64

# %%
df8["Injury Type Value"].value_counts()
# Out:
# 0    1390
# 1     386
# 2      24
# 3       5
# Name: Injury Type Value, dtype: int64

# %%
df8.corr()
# Out:
#                    Injury Type Value  Number of bars
# Injury Type Value           1.000000       -0.069217
# Number of bars             -0.069217        1.000000

# %%
df8.corr().iloc[0, 1]
# Out:
# -0.06921726778921909

# %%
f"The correlation between the number of bars in the area and severity of the crash is {df8.corr().iloc[0, 1]}."
# Out:
# 'The correlation between the number of bars in the area and severity of the crash is -0.06921726778921909.'

# %% [markdown]
# This means that there is no or a negligible relationship between the number of bars in the area and severity of the crash.

# %% [markdown]
# # Visual Crossing API
#
# Virtual Crossing API documentation is [here](https://www.visualcrossing.com/resources/documentation/)
#
# 1. Sign up for FREE api key if you haven't done that before.
# 2. For each crush, get the weather for the location and date.
# 3. Find a relationship between the weather and severity of the crash.
#
# Hints:
#
# * randomly sample only 250 or so (due to API limits), or pull weather only for smaller sample of crashes
# * for sending HTTP requests check out "requests" library [here](http://docs.python-requests.org/en/master/)

# %%
df3.head(10)
# Out:
#    Master Record Number  Year  Month  Day Weekend?    Hour Collision Type  \
# 0             902363382  2015      1    5  Weekday     0.0          2-Car
# 1             902364268  2015      1    6  Weekday  1500.0          2-Car
# 2             902364412  2015      1    6  Weekend  2300.0          2-Car
# 3             902364551  2015      1    7  Weekend   900.0          2-Car
# 4             902364615  2015      1    7  Weekend  1100.0          2-Car
# 5             902364664  2015      1    6  Weekday  1800.0          2-Car
# 6             902364682  2015      1    6  Weekday  1200.0          2-Car
# 7             902364683  2015      1    6  Weekday  1400.0          1-Car
# 8             902364714  2015      1    7  Weekend  1400.0          2-Car
# 9             902364756  2015      1    7  Weekend  1600.0          1-Car
#
#           Injury Type                            Primary Factor  \
# 0   No injury/unknown     OTHER (DRIVER) - EXPLAIN IN NARRATIVE
# 1   No injury/unknown                     FOLLOWING TOO CLOSELY
# 2  Non-incapacitating                 DISREGARD SIGNAL/REG SIGN
# 3  Non-incapacitating             FAILURE TO YIELD RIGHT OF WAY
# 4   No injury/unknown             FAILURE TO YIELD RIGHT OF WAY
# 5   No injury/unknown             FAILURE TO YIELD RIGHT OF WAY
# 6   No injury/unknown  DRIVER DISTRACTED - EXPLAIN IN NARRATIVE
# 7      Incapacitating               ENGINE FAILURE OR DEFECTIVE
# 8   No injury/unknown                     FOLLOWING TOO CLOSELY
# 9   No injury/unknown                        RAN OFF ROAD RIGHT
#
#          Reported_Location   Latitude  Longitude                        ll  \
# 0               1ST & FESS  39.159207 -86.525874  39.15920668,-86.52587356
# 1            2ND & COLLEGE  39.161440 -86.534848       39.16144,-86.534848
# 2    BASSWOOD & BLOOMFIELD  39.149780 -86.568890  39.14978027,-86.56889006
# 3           GATES & JACOBS  39.165655 -86.575956    39.165655,-86.57595635
# 4                    W 3RD  39.164848 -86.579625    39.164848,-86.57962482
# 5           BURKS & WALNUT  39.126670 -86.531370  39.12666969,-86.53136998
# 6  SOUTH CURRY PIKE LOT 71  39.150825 -86.584899      39.150825,-86.584899
# 7          NORTH LOUDEN RD  39.199272 -86.637024  39.19927216,-86.63702393
# 8          LIBERTY & W 3RD  39.164610 -86.579130  39.16461021,-86.57913007
# 9        PATTERSON & W 3RD  39.163440 -86.551280  39.16344009,-86.55128002
#
#    Injury Type Value
# 0                  0
# 1                  0
# 2                  1
# 3                  1
# 4                  0
# 5                  0
# 6                  0
# 7                  2
# 8                  0
# 9                  0

# %%
df3.dtypes
# Out:
# Master Record Number      int64
# Year                      int64
# Month                     int64
# Day                       int64
# Weekend?                 object
# Hour                    float64
# Collision Type           object
# Injury Type              object
# Primary Factor           object
# Reported_Location        object
# Latitude                float64
# Longitude               float64
# ll                       object
# Injury Type Value         int64
# dtype: object

# %%
df3.shape
# Out:
# (49005, 14)

# %%
df3.dropna(subset=['Year', 'Month', 'Day', 'Hour'], inplace=True)
df3.shape
# Out:
# <ipython-input-23-02cbecb78c2d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3.dropna(subset=['Year', 'Month', 'Day', 'Hour'], inplace=True)
# (48808, 14)

# %%
df3['Hour'].unique()
# Out:
# array([   0., 1500., 2300.,  900., 1100., 1800., 1200., 1400., 1600.,
#        1700., 1300.,  700., 2100., 2000., 1900.,  400., 1000.,  600.,
#         800., 2200.,  100.,  200.,  300.,  500.])

# %%
df3['Hour'] = (df3['Hour'] / 100)
# Out:
# <ipython-input-25-427649a323ec>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Hour'] = (df3['Hour'] / 100)

# %%
df3['Hour'].unique()
# Out:
# array([ 0., 15., 23.,  9., 11., 18., 12., 14., 16., 17., 13.,  7., 21.,
#        20., 19.,  4., 10.,  6.,  8., 22.,  1.,  2.,  3.,  5.])

# %%
start_times = pd.to_datetime(df3[['Year', 'Month', 'Day', 'Hour']], utc=True)

# %%
df3['startDateTime'] = start_times.dt.strftime('%Y-%m-%dT%H:%M%:%S')
# Out:
# <ipython-input-28-35e3417a4fcd>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['startDateTime'] = start_times.dt.strftime('%Y-%m-%dT%H:%M%:%S')

# %%
df3.head(10)
# Out:
#    Master Record Number  Year  Month  Day Weekend?  Hour Collision Type  \
# 0             902363382  2015      1    5  Weekday   0.0          2-Car
# 1             902364268  2015      1    6  Weekday  15.0          2-Car
# 2             902364412  2015      1    6  Weekend  23.0          2-Car
# 3             902364551  2015      1    7  Weekend   9.0          2-Car
# 4             902364615  2015      1    7  Weekend  11.0          2-Car
# 5             902364664  2015      1    6  Weekday  18.0          2-Car
# 6             902364682  2015      1    6  Weekday  12.0          2-Car
# 7             902364683  2015      1    6  Weekday  14.0          1-Car
# 8             902364714  2015      1    7  Weekend  14.0          2-Car
# 9             902364756  2015      1    7  Weekend  16.0          1-Car
#
#           Injury Type                            Primary Factor  \
# 0   No injury/unknown     OTHER (DRIVER) - EXPLAIN IN NARRATIVE
# 1   No injury/unknown                     FOLLOWING TOO CLOSELY
# 2  Non-incapacitating                 DISREGARD SIGNAL/REG SIGN
# 3  Non-incapacitating             FAILURE TO YIELD RIGHT OF WAY
# 4   No injury/unknown             FAILURE TO YIELD RIGHT OF WAY
# 5   No injury/unknown             FAILURE TO YIELD RIGHT OF WAY
# 6   No injury/unknown  DRIVER DISTRACTED - EXPLAIN IN NARRATIVE
# 7      Incapacitating               ENGINE FAILURE OR DEFECTIVE
# 8   No injury/unknown                     FOLLOWING TOO CLOSELY
# 9   No injury/unknown                        RAN OFF ROAD RIGHT
#
#          Reported_Location   Latitude  Longitude                        ll  \
# 0               1ST & FESS  39.159207 -86.525874  39.15920668,-86.52587356
# 1            2ND & COLLEGE  39.161440 -86.534848       39.16144,-86.534848
# 2    BASSWOOD & BLOOMFIELD  39.149780 -86.568890  39.14978027,-86.56889006
# 3           GATES & JACOBS  39.165655 -86.575956    39.165655,-86.57595635
# 4                    W 3RD  39.164848 -86.579625    39.164848,-86.57962482
# 5           BURKS & WALNUT  39.126670 -86.531370  39.12666969,-86.53136998
# 6  SOUTH CURRY PIKE LOT 71  39.150825 -86.584899      39.150825,-86.584899
# 7          NORTH LOUDEN RD  39.199272 -86.637024  39.19927216,-86.63702393
# 8          LIBERTY & W 3RD  39.164610 -86.579130  39.16461021,-86.57913007
# 9        PATTERSON & W 3RD  39.163440 -86.551280  39.16344009,-86.55128002
#
#    Injury Type Value        startDateTime
# 0                  0  2015-01-05T00:00:00
# 1                  0  2015-01-06T15:00:00
# 2                  1  2015-01-06T23:00:00
# 3                  1  2015-01-07T09:00:00
# 4                  0  2015-01-07T11:00:00
# 5                  0  2015-01-06T18:00:00
# 6                  0  2015-01-06T12:00:00
# 7                  2  2015-01-06T14:00:00
# 8                  0  2015-01-07T14:00:00
# 9                  0  2015-01-07T16:00:00

# %%
end_times = start_times +  pd.Timedelta(1, unit='hour')

# %%
df3['endDateTime'] = end_times.dt.strftime('%Y-%m-%dT%H:%M%:%S')
# Out:
# <ipython-input-31-273ce890b641>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['endDateTime'] = end_times.dt.strftime('%Y-%m-%dT%H:%M%:%S')

# %%
df3.head(10)
# Out:
#    Master Record Number  Year  Month  Day Weekend?  Hour Collision Type  \
# 0             902363382  2015      1    5  Weekday   0.0          2-Car
# 1             902364268  2015      1    6  Weekday  15.0          2-Car
# 2             902364412  2015      1    6  Weekend  23.0          2-Car
# 3             902364551  2015      1    7  Weekend   9.0          2-Car
# 4             902364615  2015      1    7  Weekend  11.0          2-Car
# 5             902364664  2015      1    6  Weekday  18.0          2-Car
# 6             902364682  2015      1    6  Weekday  12.0          2-Car
# 7             902364683  2015      1    6  Weekday  14.0          1-Car
# 8             902364714  2015      1    7  Weekend  14.0          2-Car
# 9             902364756  2015      1    7  Weekend  16.0          1-Car
#
#           Injury Type                            Primary Factor  \
# 0   No injury/unknown     OTHER (DRIVER) - EXPLAIN IN NARRATIVE
# 1   No injury/unknown                     FOLLOWING TOO CLOSELY
# 2  Non-incapacitating                 DISREGARD SIGNAL/REG SIGN
# 3  Non-incapacitating             FAILURE TO YIELD RIGHT OF WAY
# 4   No injury/unknown             FAILURE TO YIELD RIGHT OF WAY
# 5   No injury/unknown             FAILURE TO YIELD RIGHT OF WAY
# 6   No injury/unknown  DRIVER DISTRACTED - EXPLAIN IN NARRATIVE
# 7      Incapacitating               ENGINE FAILURE OR DEFECTIVE
# 8   No injury/unknown                     FOLLOWING TOO CLOSELY
# 9   No injury/unknown                        RAN OFF ROAD RIGHT
#
#          Reported_Location   Latitude  Longitude                        ll  \
# 0               1ST & FESS  39.159207 -86.525874  39.15920668,-86.52587356
# 1            2ND & COLLEGE  39.161440 -86.534848       39.16144,-86.534848
# 2    BASSWOOD & BLOOMFIELD  39.149780 -86.568890  39.14978027,-86.56889006
# 3           GATES & JACOBS  39.165655 -86.575956    39.165655,-86.57595635
# 4                    W 3RD  39.164848 -86.579625    39.164848,-86.57962482
# 5           BURKS & WALNUT  39.126670 -86.531370  39.12666969,-86.53136998
# 6  SOUTH CURRY PIKE LOT 71  39.150825 -86.584899      39.150825,-86.584899
# 7          NORTH LOUDEN RD  39.199272 -86.637024  39.19927216,-86.63702393
# 8          LIBERTY & W 3RD  39.164610 -86.579130  39.16461021,-86.57913007
# 9        PATTERSON & W 3RD  39.163440 -86.551280  39.16344009,-86.55128002
#
#    Injury Type Value        startDateTime          endDateTime
# 0                  0  2015-01-05T00:00:00  2015-01-05T01:00:00
# 1                  0  2015-01-06T15:00:00  2015-01-06T16:00:00
# 2                  1  2015-01-06T23:00:00  2015-01-07T00:00:00
# 3                  1  2015-01-07T09:00:00  2015-01-07T10:00:00
# 4                  0  2015-01-07T11:00:00  2015-01-07T12:00:00
# 5                  0  2015-01-06T18:00:00  2015-01-06T19:00:00
# 6                  0  2015-01-06T12:00:00  2015-01-06T13:00:00
# 7                  2  2015-01-06T14:00:00  2015-01-06T15:00:00
# 8                  0  2015-01-07T14:00:00  2015-01-07T15:00:00
# 9                  0  2015-01-07T16:00:00  2015-01-07T17:00:00

# %%
import requests
api_key = os.environ["VISUAL_CROSSING_API_KEY"]

# %%
url = "https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/weatherdata/history"

# %%
def get_weather(coords, start_time, end_time):
    """Returns a response from an HTTP request which contains information 
    about the weather from the start time to the end time at the 
    input coordinates."""
    
    params_gw = {"locations": coords,
                 "aggregateHours": 1,
                 "unitGroup": 'metric',
                 "startDateTime": start_time,
                 "endDateTime": end_time,
                 "shortColumnNames": 'false',
                 "contentType": 'json',
                 "locationMode": 'single',
                 "key": api_key
    }
    
    response = requests.get(url, params = params_gw)
    return response.json()

# %%
coords0 = df3['ll'].iloc[0]
start_time0 = df3['startDateTime'].iloc[0]
end_time0 = df3['endDateTime'].iloc[0]

print(coords0)
print(start_time0)
print(end_time0)
# Out:
# 39.15920668,-86.52587356
# 2015-01-05T00:00:00
# 2015-01-05T01:00:00

# %%
practice_0 = get_weather(coords0, start_time0, end_time0)
practice_0
# Out:
# {'columns': {'wdir': {'id': 'wdir',
#    'name': 'Wind Direction',
#    'type': 2,
#    'unit': None},
#   'latitude': {'id': 'latitude', 'name': 'Latitude', 'type': 2, 'unit': None},
#   'cloudcover': {'id': 'cloudcover',
#    'name': 'Cloud Cover',
#    'type': 2,
#    'unit': '%'},
#   'mint': {'id': 'mint',
#    'name': 'Minimum Temperature',
#    'type': 2,
#    'unit': 'degC'},
#   'datetime': {'id': 'datetime', 'name': 'Date time', 'type': 3, 'unit': None},
#   'precip': {'id': 'precip', 'name': 'Precipitation', 'type': 2, 'unit': 'mm'},
#   'solarradiation': {'id': 'solarradiation',
#    'name': 'Solar Radiation',
#    'type': 2,
#    'unit': 'null/m^2'},
#   'dew': {'id': 'dew', 'name': 'Dew Point', 'type': 2, 'unit': 'degC'},
#   'humidity': {'id': 'humidity',
#    'name': 'Relative Humidity',
#    'type': 2,
#    'unit': '%'},
#   'precipcover': {'id': 'precipcover',
#    'name': 'Precipitation Cover',
#    'type': 2,
#    'unit': '%'},
#   'longitude': {'id': 'longitude',
#    'name': 'Longitude',
#    'type': 2,
#    'unit': None},
#   'info': {'id': 'info', 'name': 'Info', 'type': 1, 'unit': None},
#   'temp': {'id': 'temp', 'name': 'Temperature', 'type': 2, 'unit': 'degC'},
#   'address': {'id': 'address', 'name': 'Address', 'type': 1, 'unit': None},
#   'maxt': {'id': 'maxt',
#    'name': 'Maximum Temperature',
#    'type': 2,
#    'unit': 'degC'},
#   'visibility': {'id': 'visibility',
#    'name': 'Visibility',
#    'type': 2,
#    'unit': 'km'},
#   'wspd': {'id': 'wspd', 'name': 'Wind Speed', 'type': 2, 'unit': 'kph'},
#   'solarenergy': {'id': 'solarenergy',
#    'name': 'Solar Energy',
#    'type': 2,
#    'unit': 'null/m^2'},
#   'resolvedAddress': {'id': 'resolvedAddress',
#    'name': 'Resolved Address',
#    'type': 1,
#    'unit': None},
#   'heatindex': {'id': 'heatindex',
#    'name': 'Heat Index',
#    'type': 2,
#    'unit': 'degC'},
#   'weathertype': {'id': 'weathertype',
#    'name': 'Weather Type',
#    'type': 1,
#    'unit': None},
#   'snowdepth': {'id': 'snowdepth',
#    'name': 'Snow Depth',
#    'type': 2,
#    'unit': 'cm'},
#   'sealevelpressure': {'id': 'sealevelpressure',
#    'name': 'Sea Level Pressure',
#    'type': 2,
#    'unit': 'mb'},
#   'snow': {'id': 'snow', 'name': 'Snow', 'type': 2, 'unit': 'cm'},
#   'name': {'id': 'name', 'name': 'Name', 'type': 1, 'unit': None},
#   'wgust': {'id': 'wgust', 'name': 'Wind Gust', 'type': 2, 'unit': 'kph'},
#   'conditions': {'id': 'conditions',
#    'name': 'Conditions',
#    'type': 1,
#    'unit': None},
#   'windchill': {'id': 'windchill',
#    'name': 'Wind Chill',
#    'type': 2,
#    'unit': 'degC'}},
#  'remainingCost': 0,
#  'queryCost': 2,
#  'messages': None,
#  'location': {'stationContributions': None,
#   'values': [{'wdir': 310.0,
#     'temp': -8.9,
#     'maxt': -8.9,
#     'visibility': 14.0,
#     'wspd': 20.7,
#     'datetimeStr': '2015-01-05T00:00:00-05:00',
#     'solarenergy': None,
#     'heatindex': None,
#     'cloudcover': 95.7,
#     'mint': -8.9,
#     'datetime': 1420416000000,
#     'precip': 0.0,
#     'solarradiation': None,
#     'weathertype': '',
#     'snowdepth': 0.0,
#     'sealevelpressure': 1033.3,
#     'snow': 0.0,
#     'dew': -12.8,
#     'humidity': 73.09,
#     'precipcover': None,
#     'wgust': 46.4,
#     'conditions': 'Overcast',
#     'windchill': -16.6,
#     'info': None},
#    {'wdir': 300.0,
#     'temp': -10.0,
#     'maxt': -10.0,
#     'visibility': 16.0,
#     'wspd': 20.7,
#     'datetimeStr': '2015-01-05T01:00:00-05:00',
#     'solarenergy': None,
#     'heatindex': None,
#     'cloudcover': 95.1,
#     'mint': -10.0,
#     'datetime': 1420419600000,
#     'precip': 0.0,
#     'solarradiation': None,
#     'weathertype': '',
#     'snowdepth': 0.0,
#     'sealevelpressure': 1034.5,
#     'snow': 0.0,
#     'dew': -13.3,
#     'humidity': 76.43,
#     'precipcover': None,
#     'wgust': 48.2,
#     'conditions': 'Overcast',
#     'windchill': -17.9,
#     'info': None}],
#   'id': '39.15920668,-86.52587356',
#   'address': '39.15920668,-86.52587356',
#   'name': '39.15920668,-86.52587356',
#   'index': 0,
#   'latitude': 39.15920668,
#   'longitude': -86.52587356,
#   'distance': 0.0,
#   'time': 0.0,
#   'tz': 'America/Indiana/Indianapolis',
#   'currentConditions': None,
#   'alerts': None}}

# %%
practice_1 = get_weather(coords0, start_time0, start_time0)
practice_1
# Out:
# {'columns': {'wdir': {'id': 'wdir',
#    'name': 'Wind Direction',
#    'type': 2,
#    'unit': None},
#   'latitude': {'id': 'latitude', 'name': 'Latitude', 'type': 2, 'unit': None},
#   'cloudcover': {'id': 'cloudcover',
#    'name': 'Cloud Cover',
#    'type': 2,
#    'unit': '%'},
#   'mint': {'id': 'mint',
#    'name': 'Minimum Temperature',
#    'type': 2,
#    'unit': 'degC'},
#   'datetime': {'id': 'datetime', 'name': 'Date time', 'type': 3, 'unit': None},
#   'precip': {'id': 'precip', 'name': 'Precipitation', 'type': 2, 'unit': 'mm'},
#   'solarradiation': {'id': 'solarradiation',
#    'name': 'Solar Radiation',
#    'type': 2,
#    'unit': 'null/m^2'},
#   'dew': {'id': 'dew', 'name': 'Dew Point', 'type': 2, 'unit': 'degC'},
#   'humidity': {'id': 'humidity',
#    'name': 'Relative Humidity',
#    'type': 2,
#    'unit': '%'},
#   'precipcover': {'id': 'precipcover',
#    'name': 'Precipitation Cover',
#    'type': 2,
#    'unit': '%'},
#   'longitude': {'id': 'longitude',
#    'name': 'Longitude',
#    'type': 2,
#    'unit': None},
#   'info': {'id': 'info', 'name': 'Info', 'type': 1, 'unit': None},
#   'temp': {'id': 'temp', 'name': 'Temperature', 'type': 2, 'unit': 'degC'},
#   'address': {'id': 'address', 'name': 'Address', 'type': 1, 'unit': None},
#   'maxt': {'id': 'maxt',
#    'name': 'Maximum Temperature',
#    'type': 2,
#    'unit': 'degC'},
#   'visibility': {'id': 'visibility',
#    'name': 'Visibility',
#    'type': 2,
#    'unit': 'km'},
#   'wspd': {'id': 'wspd', 'name': 'Wind Speed', 'type': 2, 'unit': 'kph'},
#   'solarenergy': {'id': 'solarenergy',
#    'name': 'Solar Energy',
#    'type': 2,
#    'unit': 'null/m^2'},
#   'resolvedAddress': {'id': 'resolvedAddress',
#    'name': 'Resolved Address',
#    'type': 1,
#    'unit': None},
#   'heatindex': {'id': 'heatindex',
#    'name': 'Heat Index',
#    'type': 2,
#    'unit': 'degC'},
#   'weathertype': {'id': 'weathertype',
#    'name': 'Weather Type',
#    'type': 1,
#    'unit': None},
#   'snowdepth': {'id': 'snowdepth',
#    'name': 'Snow Depth',
#    'type': 2,
#    'unit': 'cm'},
#   'sealevelpressure': {'id': 'sealevelpressure',
#    'name': 'Sea Level Pressure',
#    'type': 2,
#    'unit': 'mb'},
#   'snow': {'id': 'snow', 'name': 'Snow', 'type': 2, 'unit': 'cm'},
#   'name': {'id': 'name', 'name': 'Name', 'type': 1, 'unit': None},
#   'wgust': {'id': 'wgust', 'name': 'Wind Gust', 'type': 2, 'unit': 'kph'},
#   'conditions': {'id': 'conditions',
#    'name': 'Conditions',
#    'type': 1,
#    'unit': None},
#   'windchill': {'id': 'windchill',
#    'name': 'Wind Chill',
#    'type': 2,
#    'unit': 'degC'}},
#  'remainingCost': 0,
#  'queryCost': 1,
#  'messages': None,
#  'location': {'stationContributions': None,
#   'values': [{'wdir': 310.0,
#     'temp': -8.9,
#     'maxt': -8.9,
#     'visibility': 14.0,
#     'wspd': 20.7,
#     'datetimeStr': '2015-01-05T00:00:00-05:00',
#     'solarenergy': None,
#     'heatindex': None,
#     'cloudcover': 95.7,
#     'mint': -8.9,
#     'datetime': 1420416000000,
#     'precip': 0.0,
#     'solarradiation': None,
#     'weathertype': '',
#     'snowdepth': 0.0,
#     'sealevelpressure': 1033.3,
#     'snow': 0.0,
#     'dew': -12.8,
#     'humidity': 73.09,
#     'precipcover': None,
#     'wgust': 46.4,
#     'conditions': 'Overcast',
#     'windchill': -16.6,
#     'info': None}],
#   'id': '39.15920668,-86.52587356',
#   'address': '39.15920668,-86.52587356',
#   'name': '39.15920668,-86.52587356',
#   'index': 0,
#   'latitude': 39.15920668,
#   'longitude': -86.52587356,
#   'distance': 0.0,
#   'time': 0.0,
#   'tz': 'America/Indiana/Indianapolis',
#   'currentConditions': None,
#   'alerts': None}}

# %%
practice_1['location']['values'][0]['temp']
# Out:
# -8.9

# %% [markdown]
# It seems that we do not need the 'endDateTime' column or
# the end_time argument in the function get_weather.

# %%
def get_weather2(coords, start_time):
    """Returns a response from an HTTP request which contains information 
    about the weather at the input coordinates and start time."""
    
    params_gw2 = {"locations": coords,
                 "aggregateHours": 1,
                 "unitGroup": 'metric',
                 "startDateTime": start_time,
                 "endDateTime": start_time,
                 "shortColumnNames": 'false',
                 "contentType": 'json',
                 "locationMode": 'single',
                 "key": api_key
    }
    
    response = requests.get(url, params = params_gw2)
    return response.json()

# %%
practice_2 = get_weather2(coords0, start_time0)
practice_2
# Out:
# {'columns': {'wdir': {'id': 'wdir',
#    'name': 'Wind Direction',
#    'type': 2,
#    'unit': None},
#   'latitude': {'id': 'latitude', 'name': 'Latitude', 'type': 2, 'unit': None},
#   'cloudcover': {'id': 'cloudcover',
#    'name': 'Cloud Cover',
#    'type': 2,
#    'unit': '%'},
#   'mint': {'id': 'mint',
#    'name': 'Minimum Temperature',
#    'type': 2,
#    'unit': 'degC'},
#   'datetime': {'id': 'datetime', 'name': 'Date time', 'type': 3, 'unit': None},
#   'precip': {'id': 'precip', 'name': 'Precipitation', 'type': 2, 'unit': 'mm'},
#   'solarradiation': {'id': 'solarradiation',
#    'name': 'Solar Radiation',
#    'type': 2,
#    'unit': 'null/m^2'},
#   'dew': {'id': 'dew', 'name': 'Dew Point', 'type': 2, 'unit': 'degC'},
#   'humidity': {'id': 'humidity',
#    'name': 'Relative Humidity',
#    'type': 2,
#    'unit': '%'},
#   'precipcover': {'id': 'precipcover',
#    'name': 'Precipitation Cover',
#    'type': 2,
#    'unit': '%'},
#   'longitude': {'id': 'longitude',
#    'name': 'Longitude',
#    'type': 2,
#    'unit': None},
#   'info': {'id': 'info', 'name': 'Info', 'type': 1, 'unit': None},
#   'temp': {'id': 'temp', 'name': 'Temperature', 'type': 2, 'unit': 'degC'},
#   'address': {'id': 'address', 'name': 'Address', 'type': 1, 'unit': None},
#   'maxt': {'id': 'maxt',
#    'name': 'Maximum Temperature',
#    'type': 2,
#    'unit': 'degC'},
#   'visibility': {'id': 'visibility',
#    'name': 'Visibility',
#    'type': 2,
#    'unit': 'km'},
#   'wspd': {'id': 'wspd', 'name': 'Wind Speed', 'type': 2, 'unit': 'kph'},
#   'solarenergy': {'id': 'solarenergy',
#    'name': 'Solar Energy',
#    'type': 2,
#    'unit': 'null/m^2'},
#   'resolvedAddress': {'id': 'resolvedAddress',
#    'name': 'Resolved Address',
#    'type': 1,
#    'unit': None},
#   'heatindex': {'id': 'heatindex',
#    'name': 'Heat Index',
#    'type': 2,
#    'unit': 'degC'},
#   'weathertype': {'id': 'weathertype',
#    'name': 'Weather Type',
#    'type': 1,
#    'unit': None},
#   'snowdepth': {'id': 'snowdepth',
#    'name': 'Snow Depth',
#    'type': 2,
#    'unit': 'cm'},
#   'sealevelpressure': {'id': 'sealevelpressure',
#    'name': 'Sea Level Pressure',
#    'type': 2,
#    'unit': 'mb'},
#   'snow': {'id': 'snow', 'name': 'Snow', 'type': 2, 'unit': 'cm'},
#   'name': {'id': 'name', 'name': 'Name', 'type': 1, 'unit': None},
#   'wgust': {'id': 'wgust', 'name': 'Wind Gust', 'type': 2, 'unit': 'kph'},
#   'conditions': {'id': 'conditions',
#    'name': 'Conditions',
#    'type': 1,
#    'unit': None},
#   'windchill': {'id': 'windchill',
#    'name': 'Wind Chill',
#    'type': 2,
#    'unit': 'degC'}},
#  'remainingCost': 0,
#  'queryCost': 1,
#  'messages': None,
#  'location': {'stationContributions': None,
#   'values': [{'wdir': 310.0,
#     'temp': -8.9,
#     'maxt': -8.9,
#     'visibility': 14.0,
#     'wspd': 20.7,
#     'datetimeStr': '2015-01-05T00:00:00-05:00',
#     'solarenergy': None,
#     'heatindex': None,
#     'cloudcover': 95.7,
#     'mint': -8.9,
#     'datetime': 1420416000000,
#     'precip': 0.0,
#     'solarradiation': None,
#     'weathertype': '',
#     'snowdepth': 0.0,
#     'sealevelpressure': 1033.3,
#     'snow': 0.0,
#     'dew': -12.8,
#     'humidity': 73.09,
#     'precipcover': None,
#     'wgust': 46.4,
#     'conditions': 'Overcast',
#     'windchill': -16.6,
#     'info': None}],
#   'id': '39.15920668,-86.52587356',
#   'address': '39.15920668,-86.52587356',
#   'name': '39.15920668,-86.52587356',
#   'index': 0,
#   'latitude': 39.15920668,
#   'longitude': -86.52587356,
#   'distance': 0.0,
#   'time': 0.0,
#   'tz': 'America/Indiana/Indianapolis',
#   'currentConditions': None,
#   'alerts': None}}

# %%
practice_2['location']['values'][0]['temp']
# Out:
# -8.9

# %%
def get_temp(coords, start_time):
    """Returns the temperature in degrees Celsius 
    at the input coordinates and start time."""
    
    response = get_weather2(coords, start_time)
    temp = response['location']['values'][0]['temp']
    return temp

# %%
get_temp(coords0, start_time0)
# Out:
# -8.9

# %%
df3.head().apply(lambda x: get_temp(x['ll'], x['startDateTime']), axis=1)
# Out:
# 0    -8.9
# 1    -3.9
# 2   -10.0
# 3   -14.4
# 4   -13.9
# dtype: float64

# %%
# We will take a random sample of size 200 of the records.

df_sample3 = df3.sample(n=200)
len(df_sample3)
# Out:
# 200

# %%
df_sample3.head(10)
# Out:
#        Master Record Number  Year  Month  Day Weekend?  Hour Collision Type  \
# 53068                502526  2003     10    7  Weekend  13.0          2-Car
# 42311               1791260  2005     12    2  Weekday  15.0          2-Car
# 3514              902547203  2015     10    3  Weekday  17.0          2-Car
# 1050              902416995  2015      3    1  Weekend  10.0          2-Car
# 50841                502281  2003      3    4  Weekday  20.0          1-Car
# 50990                283556  2003      5    6  Weekday  14.0          2-Car
# 6879              902168980  2014      1    7  Weekend  12.0     Pedestrian
# 50238                502282  2003      3    5  Weekday  16.0          2-Car
# 44195               1748061  2005      7    6  Weekday  15.0        3+ Cars
# 22749             901543641  2010     12    5  Weekday  17.0          2-Car
#
#               Injury Type                         Primary Factor  \
# 53068   No injury/unknown              ROADWAY SURFACE CONDITION
# 42311   No injury/unknown                         UNSAFE BACKING
# 3514   Non-incapacitating                  FOLLOWING TOO CLOSELY
# 1050    No injury/unknown          FAILURE TO YIELD RIGHT OF WAY
# 50841   No injury/unknown                                    NaN
# 50990   No injury/unknown  OTHER (DRIVER) - EXPLAIN IN NARRATIVE
# 6879   Non-incapacitating              DISREGARD SIGNAL/REG SIGN
# 50238  Non-incapacitating  OTHER (DRIVER) - EXPLAIN IN NARRATIVE
# 44195  Non-incapacitating                  FOLLOWING TOO CLOSELY
# 22749   No injury/unknown          FAILURE TO YIELD RIGHT OF WAY
#
#             Reported_Location   Latitude  Longitude  \
# 53068      RHORER & WALNUT ST  39.121440 -86.526496
# 42311          10TH & 10TH ST  39.171472 -86.509376
# 3514   CONSTITUTION & LIBERTY  39.148729 -86.575914
# 1050                    W 3RD  39.164848 -86.575882
# 50841           SR48 & VERNAL  39.168991 -86.664580
# 50990          7TH & UNION ST  39.167255 -86.509301
# 6879         2ND ST & COLLEGE  39.161380 -86.534930
# 50238            SR37 & VERNA  39.176544 -86.562400
# 44195           ROGERS & SARE  39.135840 -86.496288
# 22749    E 3RD ST & JEFFERSON  39.164304 -86.506992
#
#                                    ll  Injury Type Value        startDateTime  \
# 53068             39.12144,-86.526496                  0  2003-10-07T13:00:00
# 42311   39.171471999999994,-86.509376                  0  2005-12-02T15:00:00
# 3514         39.14872891,-86.57591446                  1  2015-10-03T17:00:00
# 1050           39.164848,-86.57588174                  0  2015-03-01T10:00:00
# 50841        39.16899073,-86.66458038                  0  2003-03-04T20:00:00
# 50990  39.16725453,-86.50930090000001                  0  2003-05-06T14:00:00
# 6879         39.16138016,-86.53492994                  1  2014-01-07T12:00:00
# 50238              39.176544,-86.5624                  1  2003-03-05T16:00:00
# 44195             39.13584,-86.496288                  1  2005-07-06T15:00:00
# 22749    39.164304,-86.50699200000001                  0  2010-12-05T17:00:00
#
#                endDateTime
# 53068  2003-10-07T14:00:00
# 42311  2005-12-02T16:00:00
# 3514   2015-10-03T18:00:00
# 1050   2015-03-01T11:00:00
# 50841  2003-03-04T21:00:00
# 50990  2003-05-06T15:00:00
# 6879   2014-01-07T13:00:00
# 50238  2003-03-05T17:00:00
# 44195  2005-07-06T16:00:00
# 22749  2010-12-05T18:00:00

# %%
df_sample3['Temperature'] = df_sample3.apply(lambda x: get_temp(x['ll'], x['startDateTime']), axis=1)

# %%
df_sample3.head()
# Out:
#        Master Record Number  Year  Month  Day Weekend?  Hour Collision Type  \
# 53068                502526  2003     10    7  Weekend  13.0          2-Car
# 42311               1791260  2005     12    2  Weekday  15.0          2-Car
# 3514              902547203  2015     10    3  Weekday  17.0          2-Car
# 1050              902416995  2015      3    1  Weekend  10.0          2-Car
# 50841                502281  2003      3    4  Weekday  20.0          1-Car
#
#               Injury Type                 Primary Factor  \
# 53068   No injury/unknown      ROADWAY SURFACE CONDITION
# 42311   No injury/unknown                 UNSAFE BACKING
# 3514   Non-incapacitating          FOLLOWING TOO CLOSELY
# 1050    No injury/unknown  FAILURE TO YIELD RIGHT OF WAY
# 50841   No injury/unknown                            NaN
#
#             Reported_Location   Latitude  Longitude  \
# 53068      RHORER & WALNUT ST  39.121440 -86.526496
# 42311          10TH & 10TH ST  39.171472 -86.509376
# 3514   CONSTITUTION & LIBERTY  39.148729 -86.575914
# 1050                    W 3RD  39.164848 -86.575882
# 50841           SR48 & VERNAL  39.168991 -86.664580
#
#                                   ll  Injury Type Value        startDateTime  \
# 53068            39.12144,-86.526496                  0  2003-10-07T13:00:00
# 42311  39.171471999999994,-86.509376                  0  2005-12-02T15:00:00
# 3514        39.14872891,-86.57591446                  1  2015-10-03T17:00:00
# 1050          39.164848,-86.57588174                  0  2015-03-01T10:00:00
# 50841       39.16899073,-86.66458038                  0  2003-03-04T20:00:00
#
#                endDateTime  Temperature
# 53068  2003-10-07T14:00:00         24.0
# 42311  2005-12-02T16:00:00         -1.8
# 3514   2015-10-03T18:00:00         10.0
# 1050   2015-03-01T11:00:00         -1.1
# 50841  2003-03-04T21:00:00          7.0

# %%
df_sample4 = df_sample3.iloc[:, -4:]
df_sample4.head()
# Out:
#        Injury Type Value        startDateTime          endDateTime  \
# 53068                  0  2003-10-07T13:00:00  2003-10-07T14:00:00
# 42311                  0  2005-12-02T15:00:00  2005-12-02T16:00:00
# 3514                   1  2015-10-03T17:00:00  2015-10-03T18:00:00
# 1050                   0  2015-03-01T10:00:00  2015-03-01T11:00:00
# 50841                  0  2003-03-04T20:00:00  2003-03-04T21:00:00
#
#        Temperature
# 53068         24.0
# 42311         -1.8
# 3514          10.0
# 1050          -1.1
# 50841          7.0

# %%
df_sample4["Injury Type Value"].value_counts()
# Out:
# 0    152
# 1     46
# 2      2
# Name: Injury Type Value, dtype: int64

# %%
df_sample4.corr()
# Out:
#                    Injury Type Value  Temperature
# Injury Type Value           1.000000     0.221229
# Temperature                 0.221229     1.000000

# %%
df_sample4.corr().iloc[0, 1]
# Out:
# 0.22122945424910806

# %%
f"The correlation between the weather and severity of the crash is {df_sample4.corr().iloc[0, 1]}."
# Out:
# 'The correlation between the weather and severity of the crash is 0.22122945424910806.'

# %% [markdown]
# This means that there is a weak positive relationship between the weather and severity of the crash.
